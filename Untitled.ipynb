# %%
# !pip3 install torch torchvision torchaudio
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'c:\users\himal\pycharmprojects\pythonproject\venv\scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'c:\users\himal\pycharmprojects\pythonproject\venv\scripts\python.exe -m pip install --upgrade pip' command.
# ...
#      ------------------------------------ 255.1/255.1 KB 827.4 kB/s eta 0:00:00
# ...
#      -------------------------------------- 155.4/155.4 KB 9.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 77.1/77.1 KB 2.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.1/1.1 MB 2.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.63.0
#     Uninstalling tqdm-4.63.0:
#       Successfully uninstalled tqdm-4.63.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.0.0
#     Uninstalling setuptools-57.0.0:
#       Successfully uninstalled setuptools-57.0.0
# ...

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
#LOAD MODEL
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
model
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\Himal/.cache\torch\hub\master.zip
# YOLOv5  2023-5-7 Python-3.8.8 torch-1.11.0+cpu CPU
# requirements: C:\Users\Himal\.cache\torch\hub\requirements.txt not found, check failed.
# ...
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
# ...

# %%
img = 'https://media.gettyimages.com/id/52620584/photo/ac-milan-v-inter-milan.jpg?s=1024x1024&w=gi&k=20&c=bKvbdgRIQO2qzbO8fZnA5LICLMeA9GBgdsGEpcN2z-M='
results = model(img)
results.print()
# Out:
# image 1/1: 610x1024 2 persons, 1 sports ball
# Speed: 400.9ms pre-process, 373.4ms inference, 3.0ms NMS per image at shape (1, 3, 384, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results.render()
# Out:
# [array([[[250, 179, 193],
#          [250, 179, 193],
#          [249, 178, 192],
#          ...,
#          [185, 117, 130],
#          [181, 113, 126],
#          [175, 107, 120]],
#
#         [[248, 177, 191],
#          [248, 177, 191],
#          [247, 176, 190],
#          ...,
#          [182, 114, 127],
#          [180, 112, 125],
#          [176, 108, 121]],
#
#         [[248, 177, 191],
#          [247, 176, 190],
#          [246, 175, 189],
#          ...,
#          [185, 114, 128],
#          [185, 117, 130],
#          [185, 117, 130]],
#
#         ...,
#
#         [[ 62,  86,  34],
#          [ 69,  96,  43],
#          [ 58,  87,  33],
#          ...,
#          [ 72,  99,  44],
#          [ 69,  97,  39],
#          [ 64,  92,  34]],
#
#         [[ 41,  72,  15],
#          [ 52,  83,  26],
#          [ 59,  92,  35],
#          ...,
#          [ 59,  87,  29],
#          [ 52,  80,  22],
#          [ 56,  84,  26]],
#
#         [[ 46,  80,  20],
# ...

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
#Training the model

import uuid   # Unique identifier
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images') #/data/images
labels = ['awake', 'drowsy']
number_imgs = 5

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    # Loop through image range
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        # Webcam feed
        ret, frame = cap.read()
        
        # Naming out image path
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
        # Writes out image to file 
        cv2.imwrite(imgname, frame)
        
        # Render to the screen
        cv2.imshow('Image Collection', frame)
        
        # 2 second delay between captures
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %%
print(os.path.join(IMAGES_PATH, labels[0]+'.'+str(uuid.uuid1())+'.jpg'))
# Out:
# data\images\awake.5be53799-ec5b-11ed-8dc5-089798cb0187.jpg

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# ...
# data\images\awake.6ffebfa7-ec5b-11ed-8312-089798cb0187.jpg
# ...
# data\images\awake.6ffebfa8-ec5b-11ed-b8b1-089798cb0187.jpg
# ...
# data\images\awake.6ffebfa9-ec5b-11ed-872a-089798cb0187.jpg
# ...
# data\images\awake.6ffebfaa-ec5b-11ed-9bf6-089798cb0187.jpg
# ...
# data\images\awake.6ffebfab-ec5b-11ed-a63d-089798cb0187.jpg
# ...
# data\images\drowsy.6ffebfac-ec5b-11ed-8b71-089798cb0187.jpg
# ...
# data\images\drowsy.6ffebfad-ec5b-11ed-9c1a-089798cb0187.jpg
# ...
# data\images\drowsy.6ffebfae-ec5b-11ed-9df4-089798cb0187.jpg
# ...
# data\images\drowsy.6ffebfaf-ec5b-11ed-9b26-089798cb0187.jpg
# ...
# data\images\drowsy.6ffebfb0-ec5b-11ed-8415-089798cb0187.jpg

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# ...
#      ---------------------------------------- 6.8/6.8 MB 5.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.9/3.9 MB 15.6 MB/s eta 0:00:00
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'c:\users\himal\pycharmprojects\pythonproject\venv\scripts\python.exe -m pip install --upgrade pip' command.
# ...
#      ---------------------------------------- 78.2/78.2 KB ? eta 0:00:00
# ...
#      ---------------------------------------- 50.1/50.1 MB 6.7 MB/s eta 0:00:00
# ...

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yaml --weights yolov5s.pt --workers 2
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=500, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5
# fatal: cannot change to 'C:\Users\Himal\PycharmProjects\pythonProject\venv\Udemy\jupyter\Drowsiness': No such file or directory
# YOLOv5  2023-5-7 Python-3.8.8 torch-1.11.0+cpu CPU
#
# ...

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp7/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\Himal/.cache\torch\hub\master.zip
# YOLOv5  2023-5-7 Python-3.8.8 torch-1.11.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img = os.path.join('data', 'images', 'drowsy.2a615da3-ec5b-11ed-b746-089798cb0187.jpg')

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 480x640 1 drowsy
# Speed: 18.4ms pre-process, 424.4ms inference, 15.6ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
